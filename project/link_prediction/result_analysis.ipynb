# %%
import pandas as pd
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from torch_geometric.utils import is_undirected, to_networkx, degree
import networkx as nx
from DatasetManager import DatasetManager
from torch_geometric.datasets import Planetoid, Twitch
from torch_geometric.utils import to_networkx

# %%
# --- Data Loading and Processing ---
csv_files = glob.glob('results/*/*.csv')
all_data = []
for f in csv_files:
    try:
        # Extract dataset name from the folder path
        dataset_name = os.path.basename(os.path.dirname(f))
        
        df = pd.read_csv(f)
        df['dataset_name'] = dataset_name
        all_data.append(df)
    except pd.errors.EmptyDataError:
        print(f"Warning: The file {f} is empty and will be skipped.")

full_df = pd.concat(all_data, ignore_index=True)
metric_cols = ['AUC', 'MRR', 'Hits@10', 'Hits@50', 'Hits@100']
for col in metric_cols:
    full_df[col] = pd.to_numeric(full_df[col], errors='coerce')

full_df.dropna(subset=metric_cols, inplace=True)
avg_df = full_df.groupby(['dataset_name', 'model_name'])[metric_cols].mean().reset_index()

avg_df
# Out:
#    dataset_name                   model_name      AUC      MRR  Hits@10  \
# 0          Cora              AdamicAdarModel  0.67365  0.20525  0.35150
# 1          Cora         CommonNeighborsModel  0.67335  0.13405  0.35150
# 2          Cora            DecisionTreeModel  0.70445  0.14995  0.38310
# 3          Cora                     GCNModel  0.79870  0.07880  0.15420
# 4          Cora               GraphSAGEModel  0.70350  0.02000  0.05940
# 5          Cora            JaccardIndexModel  0.67305  0.14590  0.35150
# 6          Cora      LogisticRegressionModel  0.70255  0.18030  0.37805
# 7          Cora  PreferentialAttachmentModel  0.62245  0.07145  0.12010
# 8     Twitch-DE              AdamicAdarModel  0.87635  0.05915  0.11625
# 9     Twitch-DE         CommonNeighborsModel  0.86580  0.05490  0.10350
# 10    Twitch-DE            DecisionTreeModel  0.93135  0.00860  0.00000
# 11    Twitch-DE                     GCNModel  0.93700  0.04890  0.10010
# 12    Twitch-DE               GraphSAGEModel  0.91250  0.03500  0.07770
# 13    Twitch-DE            JaccardIndexModel  0.78270  0.05935  0.05930
# 14    Twitch-DE      LogisticRegressionModel  0.92655  0.01150  0.00000
# 15    Twitch-DE  PreferentialAttachmentModel  0.88010  0.02575  0.05825
# 16    Twitch-EN              AdamicAdarModel  0.78590  0.22715  0.33130
# 17    Twitch-EN         CommonNeighborsModel  0.78395  0.16800  0.25300
# 18    Twitch-EN            DecisionTreeModel  0.89360  0.02495  0.00000
# 19    Twitch-EN                     GCNModel  0.90940  0.12760  0.16080
# 20    Twitch-EN               GraphSAGEModel  0.87470  0.10780  0.16600
# 21    Twitch-EN            JaccardIndexModel  0.77965  0.17110  0.17480
# 22    Twitch-EN      LogisticRegressionModel  0.89535  0.06990  0.24070
# 23    Twitch-EN  PreferentialAttachmentModel  0.78000  0.04805  0.09960
#
#     Hits@50  Hits@100
# 0   0.35150   0.35150
# 1   0.35150   0.35150
# 2   0.47220   0.53285
# 3   0.48420   0.58530
# 4   0.25160   0.40830
# 5   0.35150   0.35150
# 6   0.46965   0.52210
# 7   0.24590   0.31480
# 8   0.26270   0.33990
# 9   0.21700   0.27890
# 10  0.19275   0.32715
# 11  0.21200   0.31110
# 12  0.21410   0.29490
# 13  0.06500   0.07470
# 14  0.23155   0.33405
# 15  0.15385   0.23385
# 16  0.47085   0.54045
# 17  0.36990   0.36990
# 18  0.46755   0.57555
# 19  0.39120   0.52290
# 20  0.30200   0.37850
# 21  0.23735   0.30465
# 22  0.48715   0.57900
# 23  0.22920   0.33145

# %%
datasets_to_analyze = sorted(avg_df['dataset_name'].unique()) if not avg_df.empty else []
print(f"Ready to analyze {len(datasets_to_analyze)} datasets: {datasets_to_analyze}")
# Out:
# Ready to analyze 3 datasets: ['Cora', 'Twitch-DE', 'Twitch-EN']

# %%
network_stats = []
datasets_to_analyze = sorted(avg_df['dataset_name'].unique()) if not avg_df.empty else []

print(f"Analyzing {len(datasets_to_analyze)} datasets to gather network statistics...")

for dataset_name in datasets_to_analyze:
    print(f"  - Processing {dataset_name}...")
    
    path = '/tmp/'
    if dataset_name.lower().startswith('twitch'):
        country_code = dataset_name.split('-')[-1].upper()
        dataset = Twitch(root=path + "Twitch", name=country_code)
    elif dataset_name.lower() in ['cora', 'citeseer', 'pubmed']:
        dataset = Planetoid(root=path + dataset_name, name=dataset_name)
    else:
        print(f"    Warning: Skipping '{dataset_name}', direct loading not configured.")
        continue

    full_graph_data = dataset[0]
    
    G = to_networkx(full_graph_data, to_undirected=True)
    
    num_nodes = full_graph_data.num_nodes
    num_edges = full_graph_data.num_edges
    
    stats_dict = {
        'Dataset': dataset_name,
        'Nodes': num_nodes,
        'Edges': num_edges,
        'Avg. Node Degree': (2 * num_edges) / num_nodes, # 2*E/N for undirected
        'Node Feature Dim.': full_graph_data.num_features,
        'Density': nx.density(G),
        'Is Connected': nx.is_connected(G),
        '# Components': nx.number_connected_components(G)
    }
    network_stats.append(stats_dict)

stats_df = pd.DataFrame(network_stats).set_index('Dataset')
display(stats_df.style.format({
    'Avg. Node Degree': '{:.2f}',
    'Density': '{:.6f}'
}))
# Out:
# Analyzing 3 datasets to gather network statistics...
#   - Processing Cora...
#   - Processing Twitch-DE...
#   - Processing Twitch-EN...
# <style type="text/css">
# </style>
# <table id="T_e6371">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6371_level0_col0" class="col_heading level0 col0" >Nodes</th>
#       <th id="T_e6371_level0_col1" class="col_heading level0 col1" >Edges</th>
#       <th id="T_e6371_level0_col2" class="col_heading level0 col2" >Avg. Node Degree</th>
#       <th id="T_e6371_level0_col3" class="col_heading level0 col3" >Node Feature Dim.</th>
#       <th id="T_e6371_level0_col4" class="col_heading level0 col4" >Density</th>
#       <th id="T_e6371_level0_col5" class="col_heading level0 col5" >Is Connected</th>
#       <th id="T_e6371_level0_col6" class="col_heading level0 col6" ># Components</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6371_level0_row0" class="row_heading level0 row0" >Cora</th>
#       <td id="T_e6371_row0_col0" class="data row0 col0" >2708</td>
#       <td id="T_e6371_row0_col1" class="data row0 col1" >10556</td>
#       <td id="T_e6371_row0_col2" class="data row0 col2" >7.80</td>
#       <td id="T_e6371_row0_col3" class="data row0 col3" >1433</td>
#       <td id="T_e6371_row0_col4" class="data row0 col4" >0.001440</td>
#       <td id="T_e6371_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_e6371_row0_col6" class="data row0 col6" >78</td>
#     </tr>
#     <tr>
#       <th id="T_e6371_level0_row1" class="row_heading level0 row1" >Twitch-DE</th>
#       <td id="T_e6371_row1_col0" class="data row1 col0" >9498</td>
#       <td id="T_e6371_row1_col1" class="data row1 col1" >315774</td>
#       <td id="T_e6371_row1_col2" class="data row1 col2" >66.49</td>
#       <td id="T_e6371_row1_col3" class="data row1 col3" >128</td>
#       <td id="T_e6371_row1_col4" class="data row1 col4" >0.003606</td>
#       <td id="T_e6371_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_e6371_row1_col6" class="data row1 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6371_level0_row2" class="row_heading level0 row2" >Twitch-EN</th>
#       <td id="T_e6371_row2_col0" class="data row2 col0" >7126</td>
#       <td id="T_e6371_row2_col1" class="data row2 col1" >77774</td>
#       <td id="T_e6371_row2_col2" class="data row2 col2" >21.83</td>
#       <td id="T_e6371_row2_col3" class="data row2 col3" >128</td>
#       <td id="T_e6371_row2_col4" class="data row2 col4" >0.001672</td>
#       <td id="T_e6371_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_e6371_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
def plot_metrics(dataset_name):
    dataset_results_df = avg_df[avg_df['dataset_name'] == dataset_name].sort_values(by='AUC', ascending=False)
 
    melted_df = dataset_results_df.melt(
        id_vars=['dataset_name', 'model_name'],
        value_vars=metric_cols,
        var_name='Metric',
        value_name='Score'
    )

    sns.set_theme(style="whitegrid")
    fig, ax = plt.subplots(figsize=(20, 8))

    barplot = sns.barplot(
        data=melted_df,
        x='model_name',
        y='Score',
        hue='Metric',
        ax=ax,
        palette='magma'
    )

    ax.set_title(f'Model Performance on {dataset_name} Dataset', fontsize=22, pad=20)
    ax.set_xlabel('Model', fontsize=16, labelpad=15)
    ax.set_ylabel('Score', fontsize=16)
    ax.tick_params(axis='x', rotation=45, labelsize=12)
    ax.tick_params(axis='y', labelsize=12)
    ax.set_ylim(0, 1.05)
    
    for p in barplot.patches:
        if p.get_height() > 0.01:
            barplot.annotate(format(p.get_height(), '.2f'),
                           (p.get_x() + p.get_width() / 2., p.get_height()),
                           ha = 'center', va = 'center',
                           xytext = (0, 9),
                           textcoords = 'offset points',
                           fontsize=9)

    plt.legend(title='Metric', fontsize=12, title_fontsize=14, bbox_to_anchor=(1.02, 1), loc='upper left')

    plt.tight_layout(rect=[0, 0, 0.9, 1])
    plt.show()

# %%
# --- 2. Plotting the model evaluation results ---
plot_metrics('Cora')

# %%
plot_metrics("Twitch-EN")

# %%
plot_metrics('Twitch-DE')
